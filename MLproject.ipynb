# %% [markdown]
# IMPORTING LIBRARIES:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# READING DATASET :

# %%
df=pd.read_csv("/content/drive/MyDrive/braintumor.csv")
df
# Out:
#     AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0             -156            -115            -140             149
# 1               16             -63             -89              92
# 2               34             -81             163             110
# 3              -72             -58              60             170
# 4             -552            -212            -191             374
# 5               33            -110             -31              12
# 6              -76             -54              97              -6
# 7             -159            -148            -474             595
# 8             -106             -14              87             177
# 9             -432            -173            -101              65
# 10            -133            -119            -162              42
# 11             -76            -289             180             -43
# 12            -433            -240             534             240
# ...

# %%
df.shape
# Out:
# (40, 7130)

# %% [markdown]
# Thus there are 40 rows and 7130 columns.

# %%
df.head()
# Out:
#    AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0            -156            -115            -140             149
# 1              16             -63             -89              92
# 2              34             -81             163             110
# 3             -72             -58              60             170
# 4            -552            -212            -191             374
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0            -111             -334              -47            -204
# 1            -394             -719              290            -132
# 2            -230             -353              158            -114
# 3            -117             -328              264             -71
# 4             -50             -404             -399             -61
#
#    AFFX-CreX-3_at  AFFX-BioB-5_st  ...  U58516_at  U73738_at  X06956_at  \
# 0            -148             377  ...       1483        -10        182
# ...

# %%
df.tail()
# Out:
#     AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 35             -72             -24            -268             122
# 36            -394            -605             827             471
# 37               8            -408              51             198
# 38             -89             -64              14             163
# 39            -106            -359              14             424
#
#     AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 35            -256             -428              345            -264
# 36            -673             -875             1654            -798
# 37            -408            -1046            -1016            -681
# 38            -143             -391             1010            -326
# 39            -548             -937             -932            -334
#
#     AFFX-CreX-3_at  AFFX-BioB-5_st  ...  U58516_at  U73738_at  X06956_at  \
# ...

# %% [markdown]
# NULL VALUES:

# %%
df.isnull().sum()
# Out:
# AFFX-BioB-5_at    0
# AFFX-BioB-M_at    0
# AFFX-BioB-3_at    0
# AFFX-BioC-5_at    0
# AFFX-BioC-3_at    0
#                  ..
# Z17240_at         0
# L49218_f_at       0
# M71243_f_at       0
# Z78285_f_at       0
# class             0
# Length: 7130, dtype: int64

# %% [markdown]
# Thus there are no null values in the dataset.

# %% [markdown]
# INFORMATION:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Columns: 7130 entries, AFFX-BioB-5_at to class
# dtypes: int64(7129), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# DESCRIPTIVE STATISTICS:

# %%
df.describe()
# Out:
#        AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# count        40.00000       40.000000       40.000000       40.000000
# mean       -255.47500     -266.075000      -10.325000      240.450000
# std         386.58863      319.380441      282.397191      222.069976
# min       -1969.00000    -1688.000000     -474.000000      -43.000000
# 25%        -250.75000     -296.750000     -185.500000       89.250000
# 50%        -120.50000     -160.500000      -95.000000      166.500000
# 75%         -76.00000     -113.750000       89.500000      374.750000
# max          34.00000       -4.000000      827.000000      867.000000
#
#        AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# count       40.000000        40.000000        40.000000       40.000000
# mean      -378.025000      -721.600000       156.075000     -292.400000
# std        244.715899       431.468381       866.059908      218.082295
# ...

# %% [markdown]
# UNIQUE VALUES:

# %%
df.nunique()
# Out:
# AFFX-BioB-5_at    35
# AFFX-BioB-M_at    38
# AFFX-BioB-3_at    39
# AFFX-BioC-5_at    38
# AFFX-BioC-3_at    40
#                   ..
# Z17240_at         40
# L49218_f_at       38
# M71243_f_at       40
# Z78285_f_at       36
# class              5
# Length: 7130, dtype: int64

# %% [markdown]
# EXPLORATORY DATA ANALYSIS:

# %%
#count plot
colours=["#f7b2b0","#8f7198", "#003f5c"]
sns.countplot(data= df, x="class",palette=colours)
# Out:
# <ipython-input-9-67a9f23aaad6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data= df, x="class",palette=colours)
# <ipython-input-9-67a9f23aaad6>:2: UserWarning:
# The palette list has fewer values (3) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data= df, x="class",palette=colours)
# <Axes: xlabel='class', ylabel='count'>

# %%
# Distribution of Class
plt.figure(figsize=(10, 6))
sns.histplot(df['class'], kde=True, bins=20, color='skyblue')
plt.title('Distribution of class')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

# %%
# Pie chart for Class distribution
class_counts = df['class'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Class Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# PREPROCESSING:

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
le=LabelEncoder()
df['class']=le.fit_transform(df['class'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Columns: 7130 entries, AFFX-BioB-5_at to class
# dtypes: int64(7130)
# memory usage: 2.2 MB

# %% [markdown]
# CORRELATION:

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()

# Extract column names with correlation coefficient greater than 0.5 for a specific target column
target_column = 'class'
high_corr_columns = correlation_matrix[target_column][correlation_matrix[target_column] > 0.5].index.tolist()

# Display the column names with correlation coefficient greater than 0.5
print(f"Columns with correlation coefficient > 0.7 for '{target_column}': {high_corr_columns}")
# Out:
# Columns with correlation coefficient > 0.7 for 'class': ['D80011_at', 'HG3345-HT3522_at', 'HG4740-HT5187_at', 'HG921-HT3995_at', 'L31860_at', 'M20919_at', 'M32639_at', 'S82240_at', 'U00951_at', 'U33837_at', 'U39657_at', 'U44060_at', 'U57452_at', 'U76272_at', 'U79255_at', 'V01514_at', 'X14362_at', 'X56465_at', 'X59656_at', 'X62822_at', 'X70070_at', 'X81420_at', 'X83543_at', 'X99894_at', 'Z48804_at', 'HG1699-HT1704_s_at', 'HG4155-HT4425_s_at', 'L00022_s_at', 'X58298_s_at', 'M33772_s_at', 'U12259_cds2_s_at', 'Z48314_s_at', 'U35637_s_at', 'class']

# %%
selected_columns=['D80011_at', 'HG3345-HT3522_at', 'HG4740-HT5187_at', 'HG921-HT3995_at', 'L31860_at', 'M20919_at', 'M32639_at', 'S82240_at', 'U00951_at', 'U33837_at', 'U39657_at', 'U44060_at', 'U57452_at', 'U76272_at', 'U79255_at', 'V01514_at', 'X14362_at', 'X56465_at', 'X59656_at', 'X62822_at', 'X70070_at', 'X81420_at', 'X83543_at', 'X99894_at', 'Z48804_at', 'HG1699-HT1704_s_at', 'HG4155-HT4425_s_at', 'L00022_s_at', 'X58298_s_at', 'M33772_s_at', 'U12259_cds2_s_at', 'Z48314_s_at', 'U35637_s_at', 'class']
heatmap_data=df[selected_columns]

# %%
correlation_matrix = heatmap_data.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(correlation_matrix,annot=True,cmap='YlGnBu',fmt='.1f')
plt.title("Heatmap")
plt.show()

# %%
abs(df.corr())[['class']].style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# #T_8c15f_row0_col0, #T_8c15f_row90_col0, #T_8c15f_row265_col0, #T_8c15f_row710_col0, #T_8c15f_row818_col0, #T_8c15f_row1139_col0, #T_8c15f_row1371_col0, #T_8c15f_row1671_col0, #T_8c15f_row1695_col0, #T_8c15f_row1716_col0, #T_8c15f_row2035_col0, #T_8c15f_row2213_col0, #T_8c15f_row2654_col0, #T_8c15f_row3026_col0, #T_8c15f_row3028_col0, #T_8c15f_row3131_col0, #T_8c15f_row3163_col0, #T_8c15f_row3275_col0, #T_8c15f_row3768_col0, #T_8c15f_row3882_col0, #T_8c15f_row3901_col0, #T_8c15f_row4204_col0, #T_8c15f_row4264_col0, #T_8c15f_row4362_col0, #T_8c15f_row4887_col0, #T_8c15f_row4920_col0, #T_8c15f_row5482_col0, #T_8c15f_row5489_col0, #T_8c15f_row5490_col0, #T_8c15f_row5708_col0, #T_8c15f_row6160_col0, #T_8c15f_row6182_col0, #T_8c15f_row6365_col0, #T_8c15f_row6584_col0, #T_8c15f_row6615_col0, #T_8c15f_row6979_col0 {
#   background-color: #a0bddb;
#   color: #000000;
# }
# ...

# %% [markdown]
# SPLITTING THE DATASET:

# %%
x= df.iloc[:,:-1].values
y= df.iloc[:,-1].values

# %% [markdown]
# AUTO SPLIT:

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from tabulate import tabulate
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score

# %%
classifiers = {
    'RandomForest':RandomForestClassifier(),
    'logistic':LogisticRegression(),'SVM':SVC()
    }

# %%
def performance(xtrain,xtest,ytrain,ytest,classifier):
  classifier.fit(xtrain,ytrain)
  ypred=classifier.predict(xtest)
  acc = accuracy_score(ytest,ypred)
  pre = precision_score(ytest,ypred,average='weighted',zero_division=1)
  rec = recall_score(ytest,ypred,average='weighted',zero_division=1)
  f1= f1_score(ytest,ypred,average='weighted',zero_division=1)
  return acc,pre,rec,f1

# %%
def find_optimal_split_ratio(x, y, classifiers, splitting_ratios):
  optimal_ratio=None
  best_cls=None
  max_accuracy = 0.0
  header=["Test Ratio", "Classifier", "Accuracy","Precision","Recall","F1-score"]
  table_data = []
  for test_ratio in splitting_ratios:
     xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=test_ratio,random_state=0)
     for classifier_name, classifier in classifiers.items():
            accuracy, precision, recall, f1 = performance(xtrain, xtest, ytrain, ytest, classifier)
            row_data = [f"{test_ratio: .2f}",classifier_name,f"{accuracy: .4f}",f"{precision: .4f}",f"{recall: .4f}",f"{f1: .4f}"]
            table_data.append(row_data)
            if accuracy> max_accuracy:
              max_accuracy = accuracy
              optimal_ratio = test_ratio
  print(f"Optimal Splitting Ratio: {optimal_ratio:.2f}")
  print("best model:", best_cls)
  print(tabulate(table_data, headers=header, tablefmt="grid"))

# %%
splitting_ratios = np.linspace(0.1,0.9)
find_optimal_split_ratio(x, y, classifiers, splitting_ratios)
# Out:
# Optimal Splitting Ratio: 0.10
# best model: None
# +--------------+--------------+------------+-------------+----------+------------+
# |   Test Ratio | Classifier   |   Accuracy |   Precision |   Recall |   F1-score |
# +==============+==============+============+=============+==========+============+
# |         0.1  | RandomForest |     1      |      1      |   1      |     1      |
# +--------------+--------------+------------+-------------+----------+------------+
# |         0.1  | logistic     |     1      |      1      |   1      |     1      |
# +--------------+--------------+------------+-------------+----------+------------+
# |         0.1  | SVM          |     0.75   |      0.875  |   0.75   |     0.7667 |
# +--------------+--------------+------------+-------------+----------+------------+
# |         0.12 | RandomForest |     1      |      1      |   1      |     1      |
# +--------------+--------------+------------+-------------+----------+------------+
# ...

# %% [markdown]
# DIMENSIONALITY REDUCTION:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Step 1: Standardize the dataset
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df)

# Step 2: Perform PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(data_scaled)

# Step 3: Visualize the results
plt.figure(figsize=(8, 6))
plt.scatter(principal_components[:, 0], principal_components[:, 1], alpha=0.5)
plt.title('PCA Visualization')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %% [markdown]
# TRAIN AND TEST SPLIT:

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# MODEL BUILDING:

# %% [markdown]
# MODEL 1 - LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# Initialize and train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("\nConfusion Matrix:")
print(conf_matrix)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# Confusion Matrix:
# [[1 0]
#  [0 3]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         3
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %%
# Cross validation score (Logistic regression)
from sklearn.model_selection import cross_val_score
score = cross_val_score(model, x, y,cv=5)
score
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# array([0.75 , 0.875, 0.875, 0.625, 0.875])

# %% [markdown]
# MODEL 2 - RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# Initialize and train the Random Forest classifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("\nConfusion Matrix:")
print(conf_matrix)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.75
# Precision: 1.0
# Recall: 0.75
# F1 Score: 0.8500000000000001
#
# Confusion Matrix:
# [[1 0 0]
#  [0 2 1]
#  [0 0 0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00         1
#            3       1.00      0.67      0.80         3
#            4       0.00      0.00      0.00         0
#
#     accuracy                           0.75         4
#    macro avg       0.67      0.56      0.60         4
# weighted avg       1.00      0.75      0.85         4
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# MODEL 3 - SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# Initialize SVM classifier
svm_classifier = SVC(kernel='linear')

# Train the SVM classifier
svm_classifier.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = svm_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("\nConfusion Matrix:")
print(conf_matrix)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
#
# Confusion Matrix:
# [[1 0]
#  [0 3]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         3
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %% [markdown]
# SUMMARY TABLE:

# %%
import pandas as pd

# Sample data
data = {
    'Model Name': ['Model 1', 'Model 1', 'Model 1', 'Model 1', 'Model 2', 'Model 2', 'Model 2', 'Model 2', 'Model 3', 'Model 3', 'Model 3', 'Model 3'],
    'Dataset': ['Accuracy', 'Precision', 'Recall', 'F1 score', 'Accuracy', 'Precision', 'Recall', 'F1 score', 'Accuracy', 'Precision', 'Recall', 'F1 score'],
    'Accuracy (%)': [1.0, 1.0, 1.0, 1.0, 0.75, 1.0, 0.75, 0.8500000000000001, 1.0, 1.0, 1.0, 1.0]
}

# Create DataFrame
df = pd.DataFrame(data)

# Pivot the DataFrame to get the summary table
summary_table = df.pivot_table(index='Model Name', columns='Dataset', values='Accuracy (%)')

# Print the summary table
print(summary_table)
# Out:
# Dataset     Accuracy  F1 score  Precision  Recall
# Model Name
# Model 1         1.00      1.00        1.0    1.00
# Model 2         0.75      0.85        1.0    0.75
# Model 3         1.00      1.00        1.0    1.00
